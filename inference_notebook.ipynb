# %%
import torch
import os
from PIL import Image
from transformers import AutoTokenizer, AutoModel
from diffusers import AutoencoderKL
from model import SingleStreamDiT
from config import Config
from latents import decode_latents_to_image, get_combined_text_embeds
from samplers import run_sampling_pipeline

FILENAME = "ema_epoch_114.pt"
CHECKPOINT_PATH = os.path.join(Config.checkpoint_dir, FILENAME)

# %%
class FlowerGenerator:
    def __init__(self):
        self.model = None
        self.vae = None
        self.tokenizer = None
        self.text_encoder = None
        
    def load_models(self, use_ema=False):
        print(f"--- LOADING MODELS TO {Config.device} ---")
        
        print(f"Loading DiT from {os.path.basename(CHECKPOINT_PATH)}...")
        self.model = SingleStreamDiT(in_channels=Config.in_channels, text_embed_dim=Config.text_embed_dim).to(Config.device)
        
        if os.path.exists(CHECKPOINT_PATH):
            checkpoint = torch.load(CHECKPOINT_PATH, map_location=Config.device)
            
            if isinstance(checkpoint, dict) and ('model_state_dict' in checkpoint or 'ema_state_dict' in checkpoint):
                if use_ema and 'ema_state_dict' in checkpoint:
                    print("Detected Full Checkpoint: Loading EMA weights (Best for inference)...")
                    state_dict = checkpoint['ema_state_dict']
                else:
                    print("Detected Full Checkpoint: Loading RAW weights (The 'Healing' weights)...")
                    state_dict = checkpoint['model_state_dict']
            else:
                print("Detected Raw State Dict: Loading directly...")
                state_dict = checkpoint
            
            self.model.load_state_dict(state_dict)
            print("DiT Weights successfully loaded.")
        else:
            print(f"!!! WARNING: {CHECKPOINT_PATH} not found. Running with random weights.")
            
        self.model.eval().to(dtype=Config.dtype)
        
        print(f"Loading VAE ({Config.vae_id})...")
        self.vae = AutoencoderKL.from_pretrained(Config.vae_id).to(Config.device, dtype=torch.float32).eval()

        print(f"Loading Text Encoder and Tokenizer ({Config.text_model_id})...")
        self.tokenizer = AutoTokenizer.from_pretrained(Config.text_model_id)
        
        full_text_model = AutoModel.from_pretrained(Config.text_model_id, trust_remote_code=True)
        self.text_encoder = full_text_model.encoder if hasattr(full_text_model, "encoder") else full_text_model
        
        self.text_encoder.to(Config.device).eval().to(dtype=Config.dtype)
        
        print("--- ALL MODELS LOADED SUCCESSFULLY ---")
        
    @torch.no_grad()
    def generate(self, prompt, neg_prompt="", steps=50, cfg=1.0, height=512, width=512, sampler="rk4", 
                 scheduler="karras", shift_val=Config.shift_val, seed=None):
        if seed is not None:
            torch.manual_seed(seed)
            
        print(f"Generating: '{prompt[:40]}...' | Size: {width}x{height} | Steps: {steps} | CFG: {cfg} | Neg: '{neg_prompt[:20]}...'")
        
        combined_text, combined_mask = get_combined_text_embeds(prompt, neg_prompt, cfg, self.tokenizer, self.text_encoder, 
                                                                Config.max_token_length, Config.device, Config.dtype)
        
        latent_h = (height // Config.vae_downsample_factor // Config.patch_size) * Config.patch_size
        latent_w = (width // Config.vae_downsample_factor // Config.patch_size) * Config.patch_size
        x = torch.randn(1, Config.in_channels, latent_h, latent_w, device=Config.device, dtype=torch.float32)

        with torch.autocast(device_type=Config.device.type if isinstance(Config.device, torch.device) else torch.device(Config.device).type, dtype=Config.dtype):
            x = run_sampling_pipeline(self.model, x, steps, combined_text, cfg, sampler, scheduler, shift_val, combined_mask)

        image = decode_latents_to_image(vae_model=self.vae, latents=x, device=Config.device)

        return image

engine = FlowerGenerator()
engine.load_models()

# %%
# Prompt from a file.
PROMPT = "no humans, star (sky), full moon, night sky, scenery, outdoors, purple flower, cloud, landscape, starry sky, grass, mountain, mountainous horizon, nature, plant"
# Mixed prompt from multiple files.
#PROMPT = "A macro shot of a blooming flower, having overlapping, velvety petals with a vibrant gradient from deep magenta to pale pink and slightly ruffled, translucent edges, the center is a dense cluster of yellow stamens with visible pollen grains, the background is blurred green foliage with soft, dappled natural daylight."
# Unconditional prompt.
#PROMPT = ""
NEGATIVE_PROMPT = ""

image = engine.generate(
    prompt=PROMPT,
    neg_prompt=NEGATIVE_PROMPT,
    steps=30,          
    cfg=2.5,
    width=544, 
    height=512,        
    sampler="dpmpp",
    scheduler="karras",
    shift_val=4.63,
    seed=42       
)

display(image)

# %%
import os
import itertools
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display

def generate_comparison_grid(
    engine,
    prompts=None,
    cfgs=None,
    steps=None,
    samplers=None,
    schedulers=None,
    width=544,
    height=512,
    shift_val=4.63,
    seed=42,
    original_image_path=None
):
    prompts = [prompts] if isinstance(prompts, str) else (prompts or [""])
    cfgs = [cfgs] if isinstance(cfgs, (float, int)) else (cfgs or [3.0])
    steps = [steps] if isinstance(steps, int) else (steps or [30])
    samplers = [samplers] if isinstance(samplers, str) else (samplers or ["euler"])
    schedulers = [schedulers] if isinstance(schedulers, str) else (schedulers or ["uniform"])

    rows = list(itertools.product(samplers, schedulers))
    cols = cfgs
    
    bg_color = (20, 20, 20)
    text_color = (255, 255, 255)
    pad = 2 
    left_label_w = 160 
    top_label_h = 40
    header_h = 50
    
    try:
        font = ImageFont.truetype("arial.ttf", 16)
        font_large = ImageFont.truetype("arial.ttf", 20)
    except:
        font = ImageFont.load_default()
        font_large = font
        
    def draw_centered_text(draw_obj, box, text, font_obj):
        x0, y0, x1, y1 = box
        try:
            bbox = draw_obj.textbbox((0, 0), text, font=font_obj)
            tw, th = bbox[2] - bbox[0], bbox[3] - bbox[1]
        except:
            tw, th = font_obj.getsize(text) if hasattr(font_obj, 'getsize') else (50, 10)
            
        tx = x0 + (x1 - x0 - tw) // 2
        ty = y0 + (y1 - y0 - th) // 2
        draw_obj.text((tx, ty), text, fill=text_color, font=font_obj)

    sub_grid_w = left_label_w + len(cols) * width + (len(cols) + 1) * pad
    sub_grid_h = header_h + top_label_h + len(rows) * height + (len(rows) + 1) * pad
    
    total_w = sub_grid_w
    total_h = sub_grid_h * len(prompts) * len(steps)
    
    ref_img = None
    if original_image_path and os.path.exists(original_image_path):
        ref_img = Image.open(original_image_path).convert("RGB")
        aspect = ref_img.width / ref_img.height
        ref_w = int(height * aspect)
        ref_img = ref_img.resize((ref_w, height), Image.LANCZOS)
        total_h += height + header_h + pad * 2
        
    canvas = Image.new("RGB", (total_w, total_h), bg_color)
    draw = ImageDraw.Draw(canvas)
    
    current_y = 0
    
    if ref_img is not None:
        draw.text((left_label_w + pad, current_y + pad + 10), "REFERENCE IMAGE", fill=text_color, font=font_large)
        current_y += header_h
        canvas.paste(ref_img, (left_label_w + pad, current_y))
        current_y += height + pad * 2
        
    for p in prompts:
        for s in steps:
            short_p = p[:90] + "..." if len(p) > 90 else p
            header_text = f"Prompt: {short_p} | Steps: {s}"
            draw.text((pad * 2, current_y + pad + 10), header_text, fill=text_color, font=font_large)
            current_y += header_h
            
            for c_idx, c in enumerate(cols):
                x_start = left_label_w + pad + c_idx * (width + pad)
                box = (x_start, current_y, x_start + width, current_y + top_label_h)
                draw_centered_text(draw, box, f"CFG: {c}", font_large)
            current_y += top_label_h
            
            for r_idx, (samp, sch) in enumerate(rows):
                row_y = current_y + r_idx * (height + pad)
                
                box = (0, row_y, left_label_w, row_y + height)
                draw_centered_text(draw, box, f"{samp.upper()}\n{sch.upper()}", font_large)
                
                for c_idx, c in enumerate(cols):
                    print(f"Generating -> Steps: {s} | CFG: {c} | {samp}+{sch}")
                    img = engine.generate(
                        prompt=p,
                        neg_prompt="",
                        steps=s,
                        cfg=c,
                        width=width,
                        height=height,
                        sampler=samp,
                        scheduler=sch,
                        shift_val=shift_val,
                        seed=seed
                    )
                    
                    x = left_label_w + pad + c_idx * (width + pad)
                    canvas.paste(img, (x, row_y))
                    
            current_y += len(rows) * (height + pad)
            
    display(canvas)
    return canvas

# %%
final_grid = generate_comparison_grid(
    engine=engine,
    prompts=["no humans, star (sky), full moon, night sky, scenery, outdoors, purple flower, cloud, landscape, starry sky, grass, mountain, mountainous horizon, nature, plant", "A stunning nocturnal landscape scene, featuring a vast starry sky and a prominent full moon illuminating the dark expanse, deep blue and teal tones dominate the atmosphere, wispy clouds drift across the night sky above rolling mountains creating a mountainous horizon, lush green grass fills the foreground where delicate purple flowers bloom amidst the natural scenery, one large luminous purple flower dominates the lower right corner catching the moonlight, scattered tiny stars pepper the inky backdrop of the night sky, suggesting a serene and mystical outdoor environment, the scene is set under the expansive canopy of the starry sky"],
    cfgs=[2.0, 2.5, 3.0],
    steps=[30],
    samplers=["euler", "dpmpp"],
    schedulers=["uniform", "karras"],
    original_image_path=r"E:\Datasets\Danbooru Dataset\downloaded_images\1349.webp"
)

final_grid.save("xyz_plot_ema_epoch114.png")
